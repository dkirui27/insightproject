# %%
import bs4
import requests
import pandas as pd
import csv
from datetime import datetime
from bs4 import BeautifulSoup

# %%
quote_page = 'https://www.thrillist.com/health/nation/best-stretches-back-shoulder-hamstring-leg-hip-flexor-stretches'

# %%
page = requests.get(quote_page).text
soup = BeautifulSoup(page, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find_all('h2')
# Out:
# [<h2>Triceps: Overhead triceps stretch</h2>,
#  <h2>Biceps: Standing biceps stretch</h2>,
#  <h2>Forearms: Alternating wrist pull</h2>,
#  <h2>Shoulders: Cross-body shoulder stretch</h2>,
#  <h2>Back: Cat, cow, child&amp;aposs pose sequence</h2>,
#  <h2>Chest: Wall-assisted single-arm chest stretch</h2>,
#  <h2>Abs: Stability ball-assisted backbend</h2>,
#  <h2>Glutes: Supine figure-4 glute stretch</h2>,
#  <h2>Quads: Standing quad stretch</h2>,
#  <h2>Hip flexors: Standing hip flexor stretch</h2>,
#  <h2>Hamstrings: Strap-assisted supine hamstring stretch</h2>,
#  <h2>Calves: Wall-assisted calf stretch</h2>]

# %%
soup.find_all('li')
# Out:
# [<li class="Headerstyles__HeaderItem-sc-1y1yog4-3 hkgJKl"><a class="Headerstyles__HeaderItemLink-sc-1y1yog4-5 dNpLUP" href="/"><span aria-label="Thrillist Thrillist means fun. We're eaters, drinkers, travelers, and doers. We serve the curious and believe that new experiences are what drive the rich lives. We bring our passion, expertise, and taste to the things that are truly worth your time and money logo. Link"><svg class="nav-header-logo" height="50px" viewbox="0 0 677.9 211.2" width="160px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><image height="636" overflow="visible" transform="matrix(.24 0 0 .24 16.855 58.538)" width="2493" xlink:href="https://assets3.thrillist.com/v1/image/2874449"/><path d="M38.4 19.8l.4 3.9c1.4 6.2 5.8 10.9 11.5 12.3l6.8.7-7.8 1.4c-5.1 1.9-8.9 6.5-10.1 12.3l-.8 6.1-2.2-7.7c-2-4.9-5.9-8.4-10.6-9.6l-6.6-1 8-2.2c3.8-1.4 7-4.4 8.8-8.4l2.6-7.8z" fill="none" stroke="#f5f0e7" stroke-linecap="round" stroke-linejoin="round" strok
# ...
